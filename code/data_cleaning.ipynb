# %% [markdown]
# # Data Cleaning

# %% [markdown]
# This notebook contains initial data preparation and cleaning for datasets from The Numbers, TMDB, and Box Office Mojo. An additional large movie dataset from Kaggle is explored at the bottom.

# %% [markdown]
# ### To-do list
#
# - Read and load data files into dataframes
# - Combine dataframes as needed (match on movie title most likely, check for others)
# - Clean up null/missing values

# %%
import pandas as pd 
from zipfile import ZipFile 
import fuzzywuzzy
import rapidfuzz

# %% [markdown]
# ## The Numbers

# %%
# Load data from The Numbers into dataframe
df_tn = pd.read_csv('../data/processed/tn.movie_budgets.csv', sep=';')
df_tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
df_tn[:20]
# Out:
#     id release_date                                        title  \
# 0    1   2009-12-18                                       Avatar
# 1    2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2    3   2019-06-07                                 Dark Phoenix
# 3    4   2015-05-01                      Avengers: Age of Ultron
# 4    5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# 5    6   2015-12-18         Star Wars Ep. VII: The Force Awakens
# 6    7   2018-04-27                       Avengers: Infinity War
# 7    8   2007-05-24   Pirates of the Caribbean: At World’s End
# 8    9   2017-11-17                               Justice League
# 9   10   2015-11-06                                      Spectre
# 10  11   2012-07-20                        The Dark Knight Rises
# 11  12   2018-05-25                      Solo: A Star Wars Story
# 12  13   2013-07-02                              The Lone Ranger
# 13  14   2012-03-09                                  John Carter
# 14  15   2010-11-24                                      Tangled
# 15  16   2007-05-04                                 Spider-Man 3
# 16  17   2016-05-06                   Captain America: Civil War
# 17  18   2016-03-25           Batman v Superman: Dawn of Justice
# 18  19   2012-12-14            The Hobbit: An Unexpected Journey
# 19  20   2009-07-15       Harry Potter and the Half-Blood Prince
#
#    production_budget domestic_gross worldwide_gross  year  month  day
# 0       $425,000,000   $760,507,625  $2,776,345,279  2009     12   18
# 1       $410,600,000   $241,063,875  $1,045,663,875  2011      5   20
# 2       $350,000,000    $42,762,350    $149,762,350  2019      6    7
# 3       $330,600,000   $459,005,868  $1,403,013,963  2015      5    1
# 4       $317,000,000   $620,181,382  $1,316,721,747  2017     12   15
# 5       $306,000,000   $936,662,225  $2,053,311,220  2015     12   18
# 6       $300,000,000   $678,815,482  $2,048,134,200  2018      4   27
# 7       $300,000,000   $309,420,425    $963,420,425  2007      5   24
# 8       $300,000,000   $229,024,295    $655,945,209  2017     11   17
# 9       $300,000,000   $200,074,175    $879,620,923  2015     11    6
# 10      $275,000,000   $448,139,099  $1,084,439,099  2012      7   20
# 11      $275,000,000   $213,767,512    $393,151,347  2018      5   25
# 12      $275,000,000    $89,302,115    $260,002,115  2013      7    2
# 13      $275,000,000    $73,058,679    $282,778,100  2012      3    9
# 14      $260,000,000   $200,821,936    $586,477,240  2010     11   24
# 15      $258,000,000   $336,530,303    $894,860,230  2007      5    4
# 16      $250,000,000   $408,084,349  $1,140,069,413  2016      5    6
# 17      $250,000,000   $330,360,194    $867,500,281  2016      3   25
# 18      $250,000,000   $303,003,568  $1,017,003,568  2012     12   14
# 19      $250,000,000   $302,089,278    $935,213,767  2009      7   15

# %%
# Create a mapping of month names to numbers
month_mapping = {
    "Jan": "01", "Feb": "02", "Mar": "03", "Apr": "04",
    "May": "05", "Jun": "06", "Jul": "07", "Aug": "08",
    "Sep": "09", "Oct": "10", "Nov": "11", "Dec": "12"
}

# %%
# Define a function to replace the month name with a number in each string
def replace_month_name(date_string):
    for month, num in month_mapping.items():
        date_string = date_string.replace(month, num)
    return date_string

# %%
# Apply the function to the 'release_date' to replace month names with numbers
df_tn['release_date'] = df_tn['release_date'].apply(replace_month_name)

# %%
# And finally, convert the 'release_date' column into datetime
df_tn['release_date'] = pd.to_datetime(df_tn['release_date'], format='%m %d, %Y')

# %%
# Split the newly converted 'release_date' column into separate columns 'year', 'month', and 'day' 
df_tn['year'] = df_tn['release_date'].dt.year 
df_tn['month'] = df_tn['release_date'].dt.month 
df_tn['day'] = df_tn['release_date'].dt.day

# %%
df_tn['year'].value_counts()[:10]
# Out:
# year
# 2015    338
# 2010    274
# 2008    264
# 2006    260
# 2014    255
# 2011    254
# 2009    239
# 2013    238
# 2012    235
# 2005    223
# Name: count, dtype: int64

# %%
# Rename 'movie' column to 'title' so it matches the TMDb table
df_tn.rename(columns={'movie': 'title'}, inplace=True)

# %% [markdown]
# #### Columns that I be needing from elsewhere mon
#
# - runtime
# - genre
# - studio?
#
# IF time allows, feature engineering on actors, directors, writers.

# %% [markdown]
# #### Merging df_tn and df_tmdb on movie title

# %%
# Merge df_tn and df_tmdb on movie title
df_tn_tmdb = pd.merge(df_tn, df_tmdb, how='inner', on='title')
df_tn_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2320 entries, 0 to 2319
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 2320 non-null   int64
#  1   release_date       2320 non-null   datetime64[ns]
#  2   title              2320 non-null   object
#  3   production_budget  2320 non-null   object
#  4   domestic_gross     2320 non-null   object
#  5   worldwide_gross    2320 non-null   object
#  6   year               2320 non-null   int32
#  7   month              2320 non-null   int32
#  8   day                2320 non-null   int32
#  9   genre_ids          2320 non-null   object
#  10  original_language  2320 non-null   object
# dtypes: datetime64[ns](1), int32(3), int64(1), object(6)
# memory usage: 172.3+ KB

# %%
df_tn_tmdb[df_tn_tmdb.duplicated(['title'],keep=False)][:30]
# Out:
#     id release_date                                    title  \
# 4    9   2017-11-17                           Justice League
# 5    9   2017-11-17                           Justice League
# 6   10   2015-11-06                                  Spectre
# 7   10   2015-11-06                                  Spectre
# 20  27   2012-05-04                             The Avengers
# 28  39   2010-05-14                               Robin Hood
# 29  39   2010-05-14                               Robin Hood
# 30  39   2010-05-14                               Robin Hood
# 31  42   2018-02-16                            Black Panther
# 32  42   2018-02-16                            Black Panther
# 34  45   2016-12-16             Rogue One: A Star Wars Story
# 35  45   2016-12-16             Rogue One: A Star Wars Story
# 39  51   2010-03-05                      Alice in Wonderland
# 50  65   2017-06-09                                The Mummy
# 55  70   2013-05-10                         The Great Gatsby
# 57  73   2015-11-25                        The Good Dinosaur
# 58  73   2015-11-25                        The Good Dinosaur
# 60  77   2012-06-22                                    Brave
# 61  77   2012-06-22                                    Brave
# 64  80   2017-10-06                        Blade Runner 2049
# 65  80   2017-10-06                        Blade Runner 2049
# 66  82   2017-11-03                           Thor: Ragnarok
# 67  82   2017-11-03                           Thor: Ragnarok
# 69  85   2016-11-18  Fantastic Beasts and Where to Find Them
# 70  85   2016-11-18  Fantastic Beasts and Where to Find Them
# 78  97   2016-04-15                          The Jungle Book
# 79  98   2015-06-19                               Inside Out
# 80  98   2015-06-19                               Inside Out
# 83   2   2017-11-22                                     Coco
# 84   2   2017-11-22                                     Coco
#
#    production_budget domestic_gross worldwide_gross  year  month  day  \
# 4       $300,000,000   $229,024,295    $655,945,209  2017     11   17
# 5       $300,000,000   $229,024,295    $655,945,209  2017     11   17
# 6       $300,000,000   $200,074,175    $879,620,923  2015     11    6
# 7       $300,000,000   $200,074,175    $879,620,923  2015     11    6
# 20      $225,000,000   $623,279,547  $1,517,935,897  2012      5    4
# 28      $210,000,000   $105,487,148    $322,459,006  2010      5   14
# 29      $210,000,000   $105,487,148    $322,459,006  2010      5   14
# 30      $210,000,000   $105,487,148    $322,459,006  2010      5   14
# 31      $200,000,000   $700,059,566  $1,348,258,224  2018      2   16
# 32      $200,000,000   $700,059,566  $1,348,258,224  2018      2   16
# 34      $200,000,000   $532,177,324  $1,049,102,856  2016     12   16
# 35      $200,000,000   $532,177,324  $1,049,102,856  2016     12   16
# 39      $200,000,000   $334,191,110  $1,025,491,110  2010      3    5
# 50      $195,000,000    $80,101,125    $409,953,905  2017      6    9
# 55      $190,000,000   $144,840,419    $351,040,419  2013      5   10
# 57      $187,500,000   $123,087,120    $333,771,037  2015     11   25
# 58      $187,500,000   $123,087,120    $333,771,037  2015     11   25
# 60      $185,000,000   $237,282,182    $554,606,532  2012      6   22
# 61      $185,000,000   $237,282,182    $554,606,532  2012      6   22
# 64      $185,000,000    $92,054,159    $259,357,408  2017     10    6
# 65      $185,000,000    $92,054,159    $259,357,408  2017     10    6
# 66      $180,000,000   $315,058,289    $846,980,024  2017     11    3
# 67      $180,000,000   $315,058,289    $846,980,024  2017     11    3
# 69      $180,000,000   $234,037,575    $802,402,853  2016     11   18
# 70      $180,000,000   $234,037,575    $802,402,853  2016     11   18
# 78      $175,000,000   $364,001,123    $962,854,547  2016      4   15
# 79      $175,000,000   $356,461,711    $854,235,992  2015      6   19
# 80      $175,000,000   $356,461,711    $854,235,992  2015      6   19
# 83      $175,000,000   $209,726,015    $798,008,101  2017     11   22
# 84      $175,000,000   $209,726,015    $798,008,101  2017     11   22
#
#                       genre_ids original_language
# 4             [28, 12, 14, 878]                en
# 5             [28, 12, 14, 878]                en
# 6                  [28, 12, 80]                en
# 7                  [28, 12, 80]                en
# 20                [878, 28, 12]                en
# 28                 [28, 12, 18]                en
# 29              [12, 16, 10751]                en
# 30                 [12, 28, 53]                en
# 31                     [28, 16]                en
# 32            [28, 12, 14, 878]                en
# 34                [28, 12, 878]                en
# 35                [28, 12, 878]                en
# 39              [10751, 14, 12]                en
# 50         [14, 53, 28, 12, 27]                en
# 55                  [18, 10749]                en
# 57              [12, 16, 10751]                en
# 58              [12, 16, 10751]                en
# 60                         [28]                th
# 61  [16, 12, 35, 10751, 28, 14]                en
# 64                [878, 28, 53]                en
# 65                [878, 28, 53]                en
# 66             [28, 12, 35, 14]                en
# 67             [28, 12, 35, 14]                en
# 69              [12, 10751, 14]                en
# 70              [12, 10751, 14]                en
# 78          [12, 18, 10751, 14]                en
# 79                     [18, 80]                en
# 80          [18, 35, 16, 10751]                en
# 83      [16, 10751, 35, 12, 14]                en
# 84      [16, 10751, 35, 12, 14]                en

# %%
# Check for duplicates
len(df_tn_tmdb['title'].unique())
# Out:
# 1900

# %%
# Drop duplicate titles
df_tn_tmdb.drop_duplicates(subset='title', inplace=True)
df_tn_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1900 entries, 0 to 2319
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1900 non-null   int64
#  1   release_date       1900 non-null   datetime64[ns]
#  2   title              1900 non-null   object
#  3   production_budget  1900 non-null   object
#  4   domestic_gross     1900 non-null   object
#  5   worldwide_gross    1900 non-null   object
#  6   year               1900 non-null   int32
#  7   month              1900 non-null   int32
#  8   day                1900 non-null   int32
#  9   genre_ids          1900 non-null   object
#  10  original_language  1900 non-null   object
# dtypes: datetime64[ns](1), int32(3), int64(1), object(6)
# memory usage: 155.9+ KB

# %%
df_tn_tmdb.to_csv('../data/processed/tn_tmdb_merged.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## Box Office Mojo

# %%
# Load Box Office Mojo data into dataframe
df_bom = pd.read_csv('../data/raw/bom.movie_gross.csv.gz', compression='gzip')
df_bom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df_bom.loc[df_bom['title'].str.contains('Harry Potter')]
# Out:
#                                            title studio  domestic_gross  \
# 2    Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 328  Harry Potter and the Deathly Hallows Part 2     WB     381000000.0
#
#     foreign_gross  year
# 2       664300000  2010
# 328     960500000  2011

# %%
df_bom['year'].value_counts()
# Out:
# year
# 2015    450
# 2016    436
# 2012    400
# 2011    399
# 2014    395
# 2013    350
# 2010    328
# 2017    321
# 2018    308
# Name: count, dtype: int64

# %%
df_tmdb['title'].isin(df_bom['title']).value_counts()
# Out:
# title
# False    21357
# True      2681
# Name: count, dtype: int64

# %%
df_tmdb['original_title'].isin(df_bom['title']).value_counts()
# Out:
# original_title
# False    21779
# True      2259
# Name: count, dtype: int64

# %%
df_bom['title'].isin(df_tmdb['title']).value_counts()
# Out:
# title
# True     2299
# False    1088
# Name: count, dtype: int64

# %%
df_bom['title'].isin(df_tmdb['original_title']).value_counts()
# Out:
# title
# True     1938
# False    1449
# Name: count, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## TMDB

# %%
# Load TMDb data into dataframe
df_tmdb = pd.read_csv('../data/raw/tmdb.movies.csv.gz', compression='gzip')
df_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
# Convert release_date column to datetime
df_tmdb['release_date'] = pd.to_datetime(df_tmdb['release_date'], format='%Y-%m-%d')

# %%
df_tmdb.sample(10)
# Out:
#        Unnamed: 0       genre_ids      id original_language  \
# 6385         6385     [18, 10751]  154537                en
# 4167         4167              []  410534                en
# 17             17  [10402, 10749]   52371                nl
# 9722         9722            [18]   82527                en
# 5145         5145            [53]   64767                en
# 23984       23984     [35, 10402]  353616                en
# 18820       18820            [99]  379500                en
# 4931         4931            [99]  240863                pt
# 12091       12091            [27]  336294                en
# 17653       17653    [18, 80, 53]  393717                fr
#
#                                           original_title  popularity  \
# 6385                                             Arcadia       1.365
# 4167   Path to Glory: The Rise and Rise of the Polish...       0.827
# 17                                            LelleBelle      18.586
# 9722                                       Dirty Dancing       0.806
# 5145                                            Deadrise       0.600
# 23984                                    Pitch Perfect 3      14.890
# 18820                                      Under the Gun       1.424
# 4931                                               Laura       0.600
# 12091      American Guinea Pig: Bouquet of Guts and Gore       2.148
# 17653                                          Braqueurs       8.826
#
#       release_date                                              title  \
# 6385    2012-10-13                                            Arcadia
# 4167    2011-04-01  Path to Glory: The Rise and Rise of the Polish...
# 17      2010-10-09                                         LelleBelle
# 9722    2013-12-05                                      Dirty Dancing
# 5145    2011-04-05                                           Deadrise
# 23984   2017-12-22                                    Pitch Perfect 3
# 18820   2016-05-13                                      Under the Gun
# 4931    2011-10-14                                              Laura
# 12091   2015-05-05      American Guinea Pig: Bouquet of Guts and Gore
# 17653   2016-09-24                                           The Crew
#
#        vote_average  vote_count
# 6385            6.1          11
# 4167           10.0           1
# 17              4.5          36
# 9722            9.3           6
# 5145            1.5           2
# 23984           6.5        1884
# 18820           5.8          11
# 4931            5.0           1
# 12091           4.7          13
# 17653           6.2         134

# %%
type(df_tmdb['genre_ids'][4166])
# Out:
# str

# %%
df_tmdb.loc[df_tmdb['genre_ids'] == '[]']
# Out:
#        Unnamed: 0 genre_ids      id original_language  \
# 517           517        []   31059                ru
# 559           559        []  151316                en
# 589           589        []   75828                en
# 689           689        []  150782                en
# 731           731        []  200946                en
# ...           ...       ...     ...               ...
# 26495       26495        []  556601                en
# 26497       26497        []  514045                en
# 26498       26498        []  497839                en
# 26500       26500        []  561932                en
# 26506       26506        []  561861                en
#
#                                original_title  popularity release_date  \
# 517                  Наша Russia: Яйца судьбы       3.867   2010-01-21
# 559                          Shrek’s Yule Log       3.424   2010-12-07
# 589                                   Erratum       3.154   2010-09-16
# 689                       Bikini Frankenstein       2.625   2010-01-18
# 731                                  Weakness       2.451   2010-10-24
# ...                                       ...         ...          ...
# 26495                               Recursion       0.600   2018-08-28
# 26497                      The Portuguese Kid       0.600   2018-02-14
# 26498  The 23rd Annual Critics' Choice Awards       0.600   2018-01-11
# 26500                                     Two       0.600   2018-02-04
# 26506                                    Eden       0.600   2018-11-25
#
#                                         title  vote_average  vote_count
# 517                Nasha Russia: Yaytsa sudby           4.3          25
# 559                          Shrek’s Yule Log           4.7           9
# 589                                   Erratum           6.6           7
# 689                       Bikini Frankenstein           6.0           4
# 731                                  Weakness           4.5           2
# ...                                       ...           ...         ...
# 26495                               Recursion           2.0           1
# 26497                      The Portuguese Kid           2.0           1
# 26498  The 23rd Annual Critics' Choice Awards           2.0           1
# 26500                                     Two           1.0           1
# 26506                                    Eden           0.0           1
#
# [2479 rows x 10 columns]

# %%
df_tmdb = df_tmdb.loc[df_tmdb['genre_ids'] != '[]']
df_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24038 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         24038 non-null  int64
#  1   genre_ids          24038 non-null  object
#  2   id                 24038 non-null  int64
#  3   original_language  24038 non-null  object
#  4   original_title     24038 non-null  object
#  5   popularity         24038 non-null  float64
#  6   release_date       24038 non-null  datetime64[ns]
#  7   title              24038 non-null  object
#  8   vote_average       24038 non-null  float64
#  9   vote_count         24038 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(4)
# memory usage: 2.0+ MB

# %%
# Split the 'release_date' column into separate columns 'year', 'month', and 'day' 
df_tmdb['year'] = df_tmdb['release_date'].dt.year 
df_tmdb['month'] = df_tmdb['release_date'].dt.month 
df_tmdb['day'] = df_tmdb['release_date'].dt.day

# %%
df_tmdb['year'].value_counts()[:15]
# Out:
# year
# 2016    2953
# 2015    2952
# 2017    2944
# 2013    2793
# 2014    2782
# 2018    2480
# 2011    2407
# 2012    2330
# 2010    2114
# 2019      63
# 2009      40
# 2008      14
# 1986      10
# 2004      10
# 2005       9
# Name: count, dtype: int64

# %%
df_tmdb['title'].isin(df_tn['movie']).value_counts()
# Out:
# title
# False    21799
# True      2239
# Name: count, dtype: int64

# %%
df_tmdb['original_title'].isin(df_tn['movie']).value_counts()
# Out:
# original_title
# False    21858
# True      2180
# Name: count, dtype: int64

# %%
df_tmdb.drop(columns=['id', 'Unnamed: 0', 'original_title', 'popularity', 'vote_average', 'vote_count', 'release_date', 'year', 'month', 'day'], inplace=True)

# %%
df_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24038 entries, 0 to 26516
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          24038 non-null  object
#  1   original_language  24038 non-null  object
#  2   title              24038 non-null  object
# dtypes: object(3)
# memory usage: 751.2+ KB

# %% [markdown]
# ---

# %% [markdown]
# ### Kaggle Movies dataset https://www.kaggle.com/datasets/mohammedalsubaie/movies

# %%
df_movies = pd.read_csv('../data/raw/movies.csv')

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 18 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   movie_id              1048575 non-null  int64
#  1   title                 1048562 non-null  object
#  2   vote_average          1048575 non-null  float64
#  3   vote_count            1048575 non-null  int64
#  4   status                1048575 non-null  object
#  5   release_date          899153 non-null   object
#  6   revenue               1048575 non-null  int64
#  7   adult                 1048575 non-null  bool
#  8   budget                1048575 non-null  int64
#  9   imdb_id               576991 non-null   object
#  10  original_language     1048575 non-null  object
#  11  original_title        1048562 non-null  object
#  12  overview              850351 non-null   object
#  13  popularity            1048575 non-null  float64
#  14  genres                646292 non-null   object
#  15  production_companies  487889 non-null   object
#  16  production_countries  602526 non-null   object
#  17  spoken_languages      620135 non-null   object
# dtypes: bool(1), float64(2), int64(4), object(11)
# memory usage: 137.0+ MB

# %%
df_movies.head()
# Out:
#              title release_date     revenue  adult     budget    imdb_id  \
# 0        Inception    7/15/2010   825532764  False  160000000  tt1375666
# 1     Interstellar    11/5/2014   701729206  False  165000000  tt0816692
# 2  The Dark Knight    7/16/2008  1004558444  False  185000000  tt0468569
# 3           Avatar   12/15/2009  2923706026  False  237000000  tt0499549
# 4     The Avengers    4/25/2012  1518815515  False  220000000  tt0848228
#
#   original_language   original_title  \
# 0                en        Inception
# 1                en     Interstellar
# 2                en  The Dark Knight
# 3                en           Avatar
# 4                en     The Avengers
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                        production_countries
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# 2  United Kingdom, United States of America
# 3  United States of America, United Kingdom
# 4                  United States of America

# %%
columns_to_drop = ['imdb_id', 'movie_id', 'vote_average', 'vote_count', 'status', 'overview', 'popularity', 'spoken_languages']
df_movies.drop(columns=columns_to_drop, inplace=True)

# %%
df_movies.drop(columns=['original_title', 'production_countries'], inplace=True)

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 8 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   title                 1048562 non-null  object
#  1   release_date          899153 non-null   object
#  2   revenue               1048575 non-null  int64
#  3   adult                 1048575 non-null  bool
#  4   budget                1048575 non-null  int64
#  5   original_language     1048575 non-null  object
#  6   genres                646292 non-null   object
#  7   production_companies  487889 non-null   object
# dtypes: bool(1), int64(2), object(5)
# memory usage: 57.0+ MB
